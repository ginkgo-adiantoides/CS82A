# %% [markdown]
# GEICO Summary Table:

# %%
import pandas as pd
pd.DataFrame({"minimum rating (out of 10)": ["4.7"], "mean (out of 10)": ["7.4"], "maximum rating (out of 10)": ["9.2"]})
# Out:
#   minimum rating (out of 10) mean (out of 10) maximum rating (out of 10)
# 0                        4.7              7.4                        9.2

# %% [markdown]
# Progressive Summary Table:

# %%
import pandas as pd
pd.DataFrame({"minimum rating (out of 10)": ["6.7"], "mean (out of 10)": ["7.667"], "maximum rating (out of 10)": ["8.9"]})
# Out:
#   minimum rating (out of 10) mean (out of 10) maximum rating (out of 10)
# 0                        6.7            7.667                        8.9

# %% [markdown]
# USAA Summary Table:

# %%
import pandas as pd
pd.DataFrame({"minimum rating (out of 10)": ["3.8"], "mean (out of 10)": ["6.067"], "maximum rating (out of 10)": ["8.1"]})
# Out:
#   minimum rating (out of 10) mean (out of 10) maximum rating (out of 10)
# 0                        3.8            6.067                        8.1

# %% [markdown]
# Based on the available ratings, the best insurance provider by far is Progressive. Not only does Progressive have the highest average rating (7.667 out of 10), but it also has the highest minimum rating (6.7 out of 10). Compare this to USAA, which has the comparatively abysmal minimum rating of 3.8 and an average of 6.067 out of 10. USAA can be dismissed out of hand, as it does not succeed in any of the three considerations of minimum, mean, and maximum ratings. The only area that Progressive is lacking in is the maximum rating: GEICO has a higher maximum rating of 9.2, which marginally supersedes Progressive's highest rating of 8.9 out of 10. The average rating is comparable for these two companies, as Progressive's mean is 7.667 and GEICO's average rating is 7.4 out of 10. However, the small increase in highest rating is not worth the trade-off of a substantially lower minimum rating, as GEICO's lowest rating is a meager 4.7 out of 10. In more tangible terms: the best service that GEICO offers may be a little better than Progressive's best, but GEICO customers risk a much, much worse customer experience than Progressive's customers do. The worst Progressive customer experience is far
